# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import (Dense, LeakyReLU, Reshape, Flatten, BatchNormalization,
                                     Dropout, Input)
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
import os

from tensorflow.keras.metrics import BinaryAccuracy

# %%
# ------------------
# Hyperparameters
# ------------------
img_rows = 28
img_cols = 28
channels = 1
img_shape = (img_rows, img_cols, channels)
latent_dim = 100
n_critic = 5  # Number of discriminator updates per generator update

# %%
# ------------------
# Load and preprocess MNIST
# ------------------
(X_train, _), (_, _) = mnist.load_data()
X_train = (X_train.astype(np.float32) - 127.5) / 127.5  # Normalize to [-1, 1]
X_train = np.expand_dims(X_train, axis=-1)

# %%
# ------------------
# Build the Generator
# ------------------
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=latent_dim))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(np.prod(img_shape), activation='tanh'))
    model.add(Reshape(img_shape))
    return model

# ------------------
# Build the Discriminator
# ------------------
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=img_shape))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
# ------------------
# Optimizers
# ------------------
opt_d = Adam(4e-4, beta_1=0.5)
opt_g = Adam(2e-4, beta_1=0.5)

# ------------------
# Build and compile Discriminator
# ------------------
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=opt_d, metrics=['accuracy'])

# ------------------
# Build Generator
# ------------------
generator = build_generator()

# ------------------
# Combined GAN
# ------------------
z = Input(shape=(latent_dim,))
img = generator(z)
discriminator.trainable = False
valid = discriminator(img)
combined = Model(z, valid)
combined.compile(loss='binary_crossentropy', optimizer=opt_g)

# — Done! —
print(discriminator.summary())
print(generator.summary())
print(combined.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 512)               401920
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 533,505
# Trainable params: 0
# Non-trainable params: 533,505
# _________________________________________________________________
# None
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               25856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1024)              525312
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 1024)              0
#
#  dense_6 (Dense)             (None, 784)               803600
#
#  reshape (Reshape)           (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 1,489,424
# Trainable params: 1,487,888
# Non-trainable params: 1,536
# _________________________________________________________________
# None
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential_1 (Sequential)   (None, 28, 28, 1)         1489424
#
#  sequential (Sequential)     (None, 1)                 533505
#
# =================================================================
# Total params: 2,022,929
# Trainable params: 1,487,888
# Non-trainable params: 535,041
# _________________________________________________________________
# None

# %%
# ------------------
# Sampling and Plotting
# ------------------
def sample_images(epoch, generator, latent_dim, output_dir="images"):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, latent_dim))
    gen_imgs = generator.predict(noise)

    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c, figsize=(5, 5))
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i, j].imshow(gen_imgs[cnt, :, :, 0], cmap='gray')
            axs[i, j].axis('off')
            cnt += 1
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    fig.savefig(f"{output_dir}/mnist_{epoch}.png")
    plt.close()

# ------------------
# Training Loop
# ------------------
d_losses = []
g_losses = []
d_accuracies = []

acc_metric = BinaryAccuracy()

def train(epochs, batch_size=128, sample_interval=50):
    half_batch = batch_size // 2

    for epoch in range(1, epochs + 1):
        idx = np.random.randint(0, X_train.shape[0], half_batch)
        real_imgs = X_train[idx]
        real_imgs += np.random.normal(0, 0.05, real_imgs.shape)

        noise = np.random.normal(0, 1, (half_batch, latent_dim))
        gen_imgs = generator.predict(noise)

        real_y = np.random.uniform(0.9, 1.0, (half_batch, 1))
        fake_y = np.random.uniform(0.0, 0.1, (half_batch, 1))

        d_loss_real = discriminator.train_on_batch(real_imgs, real_y)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake_y)

        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Compute manual accuracy
        acc_metric.reset_states()
        acc_metric.update_state(np.ones_like(real_y), discriminator.predict(real_imgs))
        acc_real = acc_metric.result().numpy()

        acc_metric.reset_states()
        acc_metric.update_state(np.zeros_like(fake_y), discriminator.predict(gen_imgs))
        acc_fake = acc_metric.result().numpy()

        acc = 0.5 * (acc_real + acc_fake)
        d_accuracies.append(acc)

        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        valid_y = np.ones((batch_size, 1))
        g_loss = combined.train_on_batch(noise, valid_y)

        d_losses.append(d_loss[0])
        g_losses.append(g_loss)

        print(f"{epoch} [D loss: {d_loss[0]:.4f}, acc.: {100*acc:.2f}%] [G loss: {g_loss:.4f}]")

        if epoch % sample_interval == 0:
            sample_images(epoch, generator, latent_dim)

# %%
# ------------------
# Start training
# ------------------
train(epochs=5000, batch_size=100, sample_interval=50)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 6ms/step
#
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 141ms/step
# 4946 [D loss: 0.6820, acc.: 81.00%] [G loss: 0.7772]
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 177ms/step
# 4947 [D loss: 0.6849, acc.: 79.00%] [G loss: 0.7881]
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 68ms/step
# 4948 [D loss: 0.6608, acc.: 77.00%] [G loss: 0.7986]
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 117ms/step
# 4949 [D loss: 0.6754, acc.: 77.00%] [G loss: 0.7755]
# 2/2 [==============================] - 0s 226ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 174ms/step
# 4950 [D loss: 0.6936, acc.: 78.00%] [G loss: 0.7532]
# 1/1 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 35ms/step
# 4951 [D loss: 0.6879, acc.: 76.00%] [G loss: 0.8147]
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 76ms/step
# 2/2 [==============================] - 0s 277ms/step
# 4952 [D loss: 0.7032, acc.: 70.00%] [G loss: 0.7921]
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 49ms/step
# 4953 [D loss: 0.6863, acc.: 78.00%] [G loss: 0.7508]
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 45ms/step
# 4954 [D loss: 0.7049, acc.: 68.00%] [G loss: 0.8097]
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 73ms/step
# 4955 [D loss: 0.7035, acc.: 77.00%] [G loss: 0.7935]
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 48ms/step
# 4956 [D loss: 0.7115, acc.: 76.00%] [G loss: 0.7729]
# 2/2 [==============================] - 0s 217ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 70ms/step
# 4957 [D loss: 0.6640, acc.: 79.00%] [G loss: 0.7834]
# 2/2 [==============================] - 0s 255ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 49ms/step
# 4958 [D loss: 0.6909, acc.: 74.00%] [G loss: 0.8318]
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 68ms/step
# 4959 [D loss: 0.7126, acc.: 73.00%] [G loss: 0.8168]
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 70ms/step
# 4960 [D loss: 0.6857, acc.: 74.00%] [G loss: 0.8190]
# 2/2 [==============================] - 0s 238ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 115ms/step
# 4961 [D loss: 0.6872, acc.: 66.00%] [G loss: 0.7868]
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 213ms/step
# 4962 [D loss: 0.6764, acc.: 71.00%] [G loss: 0.8106]
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 92ms/step
# 4963 [D loss: 0.6926, acc.: 78.00%] [G loss: 0.8061]
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 79ms/step
# 2/2 [==============================] - 0s 77ms/step
# 4964 [D loss: 0.6866, acc.: 77.00%] [G loss: 0.7855]
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 49ms/step
# 4965 [D loss: 0.6635, acc.: 79.00%] [G loss: 0.8224]
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 87ms/step
# 4966 [D loss: 0.7216, acc.: 71.00%] [G loss: 0.8050]
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 210ms/step
# 4967 [D loss: 0.6946, acc.: 72.00%] [G loss: 0.7863]
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 270ms/step
# 2/2 [==============================] - 0s 71ms/step
# 4968 [D loss: 0.6699, acc.: 78.00%] [G loss: 0.8135]
# 2/2 [==============================] - 0s 92ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 171ms/step
# 4969 [D loss: 0.7033, acc.: 71.00%] [G loss: 0.8075]
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 86ms/step
# 4970 [D loss: 0.6769, acc.: 77.00%] [G loss: 0.8008]
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 50ms/step
# 4971 [D loss: 0.6597, acc.: 80.00%] [G loss: 0.8135]
# 2/2 [==============================] - 0s 233ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 66ms/step
# 4972 [D loss: 0.6725, acc.: 74.00%] [G loss: 0.8107]
# 2/2 [==============================] - 0s 269ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 142ms/step
# 4973 [D loss: 0.7074, acc.: 66.00%] [G loss: 0.8122]
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 88ms/step
# 4974 [D loss: 0.6666, acc.: 71.00%] [G loss: 0.7703]
# 2/2 [==============================] - 0s 275ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 75ms/step
# 4975 [D loss: 0.7135, acc.: 70.00%] [G loss: 0.8072]
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 67ms/step
# 4976 [D loss: 0.7191, acc.: 70.00%] [G loss: 0.7914]
# 2/2 [==============================] - 0s 201ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 74ms/step
# 4977 [D loss: 0.6884, acc.: 76.00%] [G loss: 0.7553]
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 175ms/step
# 4978 [D loss: 0.6896, acc.: 72.00%] [G loss: 0.7710]
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 124ms/step
# 4979 [D loss: 0.6754, acc.: 75.00%] [G loss: 0.7470]
# 2/2 [==============================] - 0s 211ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 121ms/step
# 4980 [D loss: 0.6983, acc.: 72.00%] [G loss: 0.7893]
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 192ms/step
# 4981 [D loss: 0.7174, acc.: 68.00%] [G loss: 0.7777]
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 50ms/step
# 4982 [D loss: 0.6780, acc.: 75.00%] [G loss: 0.7844]
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 47ms/step
# 4983 [D loss: 0.7057, acc.: 79.00%] [G loss: 0.8015]
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 191ms/step
# 4984 [D loss: 0.7072, acc.: 73.00%] [G loss: 0.7868]
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 128ms/step
# 4985 [D loss: 0.6548, acc.: 71.00%] [G loss: 0.7694]
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 46ms/step
# 4986 [D loss: 0.7026, acc.: 72.00%] [G loss: 0.7377]
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 246ms/step
# 4987 [D loss: 0.7021, acc.: 79.00%] [G loss: 0.7810]
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 49ms/step
# 4988 [D loss: 0.6997, acc.: 73.00%] [G loss: 0.7811]
# 2/2 [==============================] - 0s 238ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 211ms/step
# 4989 [D loss: 0.6990, acc.: 74.00%] [G loss: 0.7738]
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 70ms/step
# 4990 [D loss: 0.6823, acc.: 81.00%] [G loss: 0.7874]
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 180ms/step
# 4991 [D loss: 0.6904, acc.: 71.00%] [G loss: 0.8010]
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 70ms/step
# 4992 [D loss: 0.6661, acc.: 82.00%] [G loss: 0.8101]
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 174ms/step
# 4993 [D loss: 0.6739, acc.: 71.00%] [G loss: 0.8218]
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 73ms/step
# 4994 [D loss: 0.6932, acc.: 73.00%] [G loss: 0.8106]
# 2/2 [==============================] - 0s 232ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 45ms/step
# 4995 [D loss: 0.6867, acc.: 63.00%] [G loss: 0.7836]
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 192ms/step
# 4996 [D loss: 0.7176, acc.: 75.00%] [G loss: 0.7859]
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 98ms/step
# 4997 [D loss: 0.6906, acc.: 75.00%] [G loss: 0.8052]
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 168ms/step
# 4998 [D loss: 0.6765, acc.: 73.00%] [G loss: 0.7771]
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 73ms/step
# 4999 [D loss: 0.7134, acc.: 79.00%] [G loss: 0.8103]
# 2/2 [==============================] - 0s 189ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 192ms/step
# 5000 [D loss: 0.6741, acc.: 70.00%] [G loss: 0.8043]
# 1/1 [==============================] - 0s 126ms/step

# %%
def plot_training_progress():
    plt.figure(figsize=(12, 4))

    # Plot losses
    plt.subplot(1, 2, 1)
    plt.plot(d_losses, label='Discriminator Loss')
    plt.plot(g_losses, label='Generator Loss')
    plt.title("Loss over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(d_accuracies, label='Discriminator Accuracy', color='green')
    plt.title("Discriminator Accuracy over Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.tight_layout()
    plt.show()
plot_training_progress()

# %%
# Save the generator model
generator.save("generator_model_v3.h5")

# Save the discriminator model
discriminator.save("discriminator_model_v3.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
d_losses
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d_losses
#
# NameError: name 'd_losses' is not defined
